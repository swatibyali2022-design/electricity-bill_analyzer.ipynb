# %% [markdown]
# <a href="https://colab.research.google.com/github/swatibyali2022-design/electricity-bill_analyzer.ipynb/blob/main/electricity_bill_analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Electricity Bill Calculator

# Get customer details
customer_name = input("Enter Customer Name: ")
units = float(input("Enter Units Consumed: "))

# Calculate bill amount
if units <= 100:
    bill = units * 1.5
elif units <= 200:
    bill = (100 * 1.5) + ((units - 100) * 2.5)
elif units <= 300:
    bill = (100 * 1.5) + (100 * 2.5) + ((units - 200) * 4.0)
else:
    bill = (100 * 1.5) + (100 * 2.5) + (100 * 4.0) + ((units - 300) * 6.0)

# Add fixed charge
fixed_charge = 100
total_bill = bill + fixed_charge

# Display result
print("\n----- ELECTRICITY BILL -----")
print("Customer Name :", customer_name)
print("Units Consumed:", units)
print("Bill Amount   : ₹", round(bill, 2))
print("Fixed Charge  : ₹", fixed_charge)
print("Total Bill    : ₹", round(total_bill, 2))
print("----------------------------")
# Out:
# Enter Customer Name: v
# Enter Units Consumed: 459
#
# ----- ELECTRICITY BILL -----
# Customer Name : v
# Units Consumed: 459.0
# Bill Amount   : ₹ 1754.0
# Fixed Charge  : ₹ 100
# Total Bill    : ₹ 1854.0
# ----------------------------

# %% [markdown]
# Problem Analysis
# Objective
#
# Develop a Python program to calculate the electricity bill for a customer based on the number of units consumed.
#
# Input
# Customer Name
# Number of Units Consumed
# Processing
#
# Calculate the bill according to the following tariff:
#
# Units Consumed	Rate per Unit0 - 100	₹1.50
# 101 - 200	₹2.50
# Above 200	₹4.00
#
# Additionally:
#
# Fixed Charge = ₹100
# Output
#
# Display:
#
# Customer Name
# Units Consumed
# Electricity Charges
# Fixed Charge
# Total Bill Amount
# Algorithm
# Start
# Read customer name
# Read units consumed
# Calculate bill:
# If units ≤ 100, bill = units × 1.50
# Else if units ≤ 200, bill = (100 × 1.50) + ((units − 100) × 2.50)
# Else, bill = (100 × 1.50) + (100 × 2.50) + ((units − 200) × 4.00)
# Add fixed charge of ₹100
# Compute total bill
# Display bill details
# Stop

# %% [markdown]
# Problem Breakdown (Points)
#
# Understand the Problem
#
# Calculate the electricity bill for a customer.
# Bill depends on the number of units consumed.
#
# Identify Inputs
#
# Customer Name
# Units Consumed
#
# Identify Outputs
#
# Customer Name
# Units Consumed
# Electricity Charge
# Fixed Charge
# Total Bill
#
# Determine Billing Rules
#
# First 100 units → ₹1.50 per unit
# Next 100 units → ₹2.50 per unit
# Above 200 units → ₹4.00 per unit
# Fixed charge → ₹100
#
# Calculate Electricity Charge
#
# Check the units consumed.
# Apply the appropriate slab rates.
# Compute the charge based on the slabs.
#
# Add Fixed Charge
#
# Add ₹100 to the electricity charge.
#
# Calculate Total Bill
#
# Total Bill = Electricity Charge + Fixed Charge
#
# Display Results
#
# Print all customer and bill details neatly.
# IPO Chart
#
# Input
#
# Customer Name
# Units Consumed
#
# Process
#
# Apply slab rates
# Calculate electricity charge
# Add fixed charge
# Calculate total bill
#
# Output
#
# Customer Name
# Units Consumed
# Electricity Charge
# Fixed Charge
# Total Bill Amount
